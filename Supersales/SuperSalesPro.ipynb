# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import klib

# %%
df_train = pd.read_csv("/Users/harunorrashidsajib/Desktop/SP4*/dataset/Train.csv")
df_test = pd.read_csv("/Users/harunorrashidsajib/Desktop/SP4*/dataset/Test.csv")

# %%
df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean(),inplace=True)
df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean(),inplace=True)

# %%
df_train.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)
df_test.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
# klib.clean - functions for cleaning datasets
klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (8523, 10) - Remaining NAs: 2410
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.46 MB (-70.77%)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# ...

# %%
klib.clean_column_names(df_train) # cleans and standardizes column names, also called inside data_cleaning()
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
df_train=klib.convert_datatypes(df_train) # converts existing to more efficient dtypes, also called inside data_cleaning()

# %%
klib.mv_col_handling(df_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/klib/clean.py:436: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data_local[cols_mv].applymap(lambda x: x if pd.isna(x) else 1).fillna(0)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/klib/clean.py:443: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(corrmat[col]).nlargest(2)[1] > corr_thresh_features:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_train['item_fat_content']= le.fit_transform(df_train['item_fat_content'])
df_train['item_type']= le.fit_transform(df_train['item_type'])
df_train['outlet_size']= le.fit_transform(df_train['outlet_size'])
df_train['outlet_location_type']= le.fit_transform(df_train['outlet_location_type'])
df_train['outlet_type']= le.fit_transform(df_train['outlet_type'])

# %%
#splitting train test
X=df_train.drop('item_outlet_sales',axis=1)
Y=df_train['item_outlet_sales']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state=101, test_size=0.2)

# %%
#Standardizing
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train_std= sc.fit_transform(X_train)
X_test_std= sc.transform(X_test)

# %%
import joblib
joblib.dump(sc,"/Users/harunorrashidsajib/Desktop/SP4*/models/sc.sav")
# Out:
# ['/Users/harunorrashidsajib/Desktop/SP4*/models/sc.sav']

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Assuming Y_test and Y_pred_lr are your actual and predicted values
r2 = r2_score(Y_test, Y_pred_lr)
mae = mean_absolute_error(Y_test, Y_pred_lr)
rmse = mean_squared_error(Y_test, Y_pred_lr, squared=False)  # Calculate RMSE by setting squared=False

print("R2 Score:", r2)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
# Out:
# R2 Score: 0.49385917196231155
# Mean Absolute Error: 888.7954324829681
# Root Mean Squared Error: 1174.4864247890418

# %%
joblib.dump(sc,"/Users/harunorrashidsajib/Desktop/SP4*/models/lr.sav")
# Out:
# ['/Users/harunorrashidsajib/Desktop/SP4*/models/lr.sav']

# %%
from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor(n_estimators=1000)
rf.fit(X_train_std,Y_train)
RandomForestRegressor(n_estimators=1000)
Y_pred_rf= rf.predict(X_test_std)
print(r2_score(Y_test,Y_pred_rf))
print(mean_absolute_error(Y_test,Y_pred_rf))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_rf)))
# Out:
# 0.5483293442927948
# 782.0597334267289
# 1109.489646375277
